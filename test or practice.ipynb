# %%
# import library
import pandas as pd
import numpy as np
import nltk
from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import CountVectorizer
import plotly as py
import math
# %matplotlib inline



import csv

#f=open('task1_trainset.csv','r',encoding='UTF-8')
#rdr=csv.reader(f)
#for line in rdr:
#     print(line)
#f.close()

train_data=pd.read_csv("./task1_trainset.csv")
train_data

from sklearn.feature_extraction.text import TfidfVectorizer
#text = ['task1_trainset.csv']
tfidf_vectorizer = TfidfVectorizer()

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
train_data.head() #
# Out:
#        Id                                              Title  \
# 0  D00001  A Brain-Inspired Trust Management Model to Ass...
# 1  D00002  On Efficient Computation of Shortest Dubins Pa...
# 2  D00003             Data-driven Upsampling of Point Clouds
# 3  D00004  Accessibility or Usability of InteractSE? A He...
# 4  D00005  Spatio-Temporal Facial Expression Recognition ...
#
#                                             Abstract  \
# 0  Rapid popularity of Internet of Things (IoT) a...
# 1  In this paper, we address the problem of compu...
# 2  High quality upsampling of sparse 3D point clo...
# 3  Internet is the main source of information now...
# 4  Automated Facial Expression Recognition (FER) ...
#
#                                              Authors            Categories  \
# 0  Mahmud/Kaiser/Rahman/Rahman/Shabut/Al-Mamun/Hu...  cs.CR/cs.AI/q-bio.NC
# 1                                      Sadeghi/Smith   cs.SY/cs.RO/math.OC
# ...

# %%
Id = list(train_data['Id'])
Title = list(train_data['Title'])
Abstract = list(train_data['Abstract'])
Authors = list(train_data['Authors'])
Categories = list(train_data['Categories'])
CreatedDate = list(train_data['Created Date'])
Task1= list(train_data['Task 1'])


vectorizer = TfidfVectorizer(
            min_df=0.0,
            analyzer="char",
            sublinear_tf=True,
            ngram_range=(1,3),
            max_features=5000
        )

X = vectorizer.fit_transform(Authors)

#min_df : 설정한 값보다 특정 토큰의 df값이 더 적게 나오면 벡터화 과정에서 제거
#analyzer : 분석하기 위한 기준 단위(word:단어 하나를 단위로, char:문자 하나를 단위로)
#sublinear_tf : 문서의 단어 빈도 수에 대한 스무딩(smoothing) 여부
#ngram_range : 빈도의 기본 단위를 설정할 n-gram 범위
#max_features : 각 벡터의 최대 길이

#min_df : Remove from vectoring if the df value of a particular token is less than the value which was set previously
#analyzer : Reference unit for analysis (word:one word, car:one letter)
#subline_tf : Smooting for the number of words in a document
#ngram_range : n-gram range to set the default unit of frequency
#max_features : maximum length of each vector

# %%
X
# Out:
# <7000x5000 sparse matrix of type '<class 'numpy.float64'>'
# 	with 361582 stored elements in Compressed Sparse Row format>

# %%
#tfidf_vectorizer.fit(text) # 단어를 학습시킴 
#tfidf_vectorizer.vocabulary_ # 단어사전을 출력 
#sorted(tfidf_vectorizer.vocabulary_.items()) # 단어사전 정렬
# Out:
# [('csv', 0), ('task1_trainset', 1)]

# %%
testdata[:10]
# Out:
#        Id                                              Title  \
# 0  D00001  A Brain-Inspired Trust Management Model to Ass...
# 1  D00002  On Efficient Computation of Shortest Dubins Pa...
# 2  D00003             Data-driven Upsampling of Point Clouds
# 3  D00004  Accessibility or Usability of InteractSE? A He...
# 4  D00005  Spatio-Temporal Facial Expression Recognition ...
# 5  D00006  Continuous Semantic Topic Embedding Model Usin...
# 6  D00007  Beyond Shared Hierarchies: Deep Multitask Lear...
# 7  D00008  Using Scalp Electrical Biosignals to Control a...
# 8  D00009  Robustness from structure: Inference with hier...
# 9  D00010  Statistical Mechanical Analysis of Low-Density...
#
#                                             Abstract  \
# 0  Rapid popularity of Internet of Things (IoT) a...
# 1  In this paper, we address the problem of compu...
# 2  High quality upsampling of sparse 3D point clo...
# 3  Internet is the main source of information now...
# ...

# %%
#Adding Columns
X['']
X['added_column'] = ["categories"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-56ac0b8901c5> in <module>
#       1 #Adding Columns
# ----> 2 X['added_column'] = ["categories"]
#
# NameError: name 'X' is not defined

# %%
#Familiarizing yourself with the Data
#A simpler Query
x[0:10][["Authors", "Categories"]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-3bb791fd16b2> in <module>
#       1 #Familiarizing yourself with the Data
#       2 #A simpler Query
# ----> 3 x[0:10][["Authors", "Categories"]]
#
# NameError: name 'x' is not defined
